# %%
#%cd ../
hom  = %pwd
# !echo $hom
# %pwd
# Out:
# /media/merve/Seagate Expansion Drive/sg12/mkunak19
# '/media/merve/Seagate Expansion Drive/sg12/mkunak19'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame

# %%
# %cd $hom
# %cd try14
#%cd letfree
# %cd analysis
# !ls
#%pla {hist-chi1GLN.xvg} #{hist-chi1GLN.xvg,hist-chi3GLN.xvg}#,../letfree/analysis/histo-chiGLN*.xvg}

# %cd $hom
# !pwd
# !echo $hom
# Out:
# /home/merve/sg12
# /home/merve/sg12/try14
# /home/merve/sg12/try14/analysis
# '#energy.xvg.1#'      energyall.xvg	     hbnumwall3.xvg
# '#energyall.xvg.1#'   enerout		     hbnumwall4.xvg
# '#index.ndx.1#'       hbnum-all.xvg	     hbond-full
# '#index.ndx.2#'       hbnumGLN-BB-all.xvg    hist-chi1GLN.xvg
# '#index.ndx.3#'       hbnumGLN-BBwall1.xvg   hist-chi3GLN.xvg
# '#int.xvg.1#'	      hbnumGLN-BBwall2.xvg   histfull-chi1GLN.xvg
# '#int.xvg.2#'	      hbnumGLN-BBwall3.xvg   histfull-chi3GLN.xvg
# '#int.xvg.3#'	      hbnumGLN-BBwall4.xvg   index.ndx
# '#pot.xvg.1#'	      hbnumGLN-all.xvg	     int.xvg
# '#pot.xvg.2#'	      hbnumGLNwall1.xvg      ke.xvg
# '#pot.xvg.3#'	      hbnumGLNwall2.xvg      mycommands.sh
# '#pot.xvg.4#'	      hbnumGLNwall3.xvg      pot.xvg
#  chi500ps	      hbnumGLNwall4.xvg      tot.xvg
#  chifull	      hbnumwall1.xvg	     trajout.xtc
#  energy.xvg	      hbnumwall2.xvg	     wall2wall.xvg
# /home/merve/sg12
# /home/merve/sg12
# /home/merve/sg12

# %%
#### ramachandran for chi angles ###
nbinsx = np.int(360/2.5)
nbinsy = nbinsx

SIGromos1 = np.loadtxt(fname = "try14/letfree/analysis/chi99ns/chi1GLNall.xvg")[:,1]#hist-chi1GLN.xvg")[:,1]
SIGromos3 = np.loadtxt(fname = "try14/letfree/analysis/chi99ns/chi3GLNall.xvg")[:,1]

AIGromos1 = np.loadtxt(fname = "try13/letfree/analysis/chi99ns/chi1GLNall.xvg")[:,1]
AIGromos3 = np.loadtxt(fname = "try13/letfree/analysis/chi99ns/chi3GLNall.xvg")[:,1]


SICharmm1 = np.loadtxt(fname = "try14_Charmm/analysis_merve/chi99ns/chi1GLNall.xvg")[:,1]
SICharmm3 = np.loadtxt(fname = "try14_Charmm/analysis_merve/chi99ns/chi3GLNall.xvg")[:,1]

AICharmm1 = np.loadtxt(fname = "try13_Charmm/analysis_merve/chi/chi1GLNall.xvg")[:,1]
AICharmm3 = np.loadtxt(fname = "try13_Charmm/analysis_merve/chi/chi3GLNall.xvg")[:,1]

# %%
plt.figure(1)
hist2d,xbins,ybins,fig=plt.hist2d(SIGromos1,SIGromos3,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('SI Gromos')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaSIg.pdf')
plt.show()

gfile=open("datagnu_SIg.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()

plt.figure(2)
hist2d,xbins,ybins,fig=plt.hist2d(AIGromos1,AIGromos3,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('AI Gromos')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaAIg.pdf')
plt.show()

gfile=open("datagnu_AIg.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()


plt.figure(3)
hist2d,xbins,ybins,fig=plt.hist2d(SICharmm1,SICharmm3,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('SI Charmm')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaSIc.pdf')
plt.show()

gfile=open("datagnu_SIc.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()

plt.figure(4)
hist2d,xbins,ybins,fig=plt.hist2d(AICharmm1,AICharmm3,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('AI Charmm')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaAIc.pdf')
plt.show()

gfile=open("datagnu_AIc.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()

# %%
#### ramachandran for chi angles ###
nbinsx = np.int(360/2.5)
nbinsy = nbinsx

SIGromos1rest = np.loadtxt(fname = "try14/analysis/chi500ps/chi1GLNall.xvg")[:,1]
SIGromos3rest = np.loadtxt(fname = "try14/analysis/chi500ps/chi3GLNall.xvg")[:,1]

AIGromos1rest = np.loadtxt(fname = "try13/analysis/chi500ps/chi1GLNall.xvg")[:,1]
AIGromos3rest = np.loadtxt(fname = "try13/analysis/chi500ps/chi3GLNall.xvg")[:,1]


SICharmm1rest = np.loadtxt(fname = "try14_Charmm/restraint/analysis/chi500ps/chi1GLNall.xvg")[:,1]
SICharmm3rest = np.loadtxt(fname = "try14_Charmm/restraint/analysis/chi500ps/chi3GLNall.xvg")[:,1]

AICharmm1rest = np.loadtxt(fname = "try13_Charmm/restraint/analysis/chi500ps/chi1GLNall.xvg")[:,1]
AICharmm3rest = np.loadtxt(fname = "try13_Charmm/restraint/analysis/chi500ps/chi3GLNall.xvg")[:,1]

# %%
plt.figure(1)
hist2d,xbins,ybins,fig=plt.hist2d(SIGromos1rest,SIGromos3rest,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('SI Gromos')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaSIgR.pdf')
plt.show()

gfile=open("datagnu_SIgr.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()

plt.figure(2)
hist2d,xbins,ybins,fig=plt.hist2d(AIGromos1rest,AIGromos3rest,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('AI Gromos')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaAIgR.pdf')
plt.show()
gfile=open("datagnu_AIgr.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()

plt.figure(3)
hist2d,xbins,ybins,fig=plt.hist2d(SICharmm1rest,SICharmm3rest,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('SI Charmm')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaSIcR.pdf')
plt.show()

gfile=open("datagnu_SIcr.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()

plt.figure(4)
hist2d,xbins,ybins,fig=plt.hist2d(AICharmm1rest,AICharmm3rest,bins=[nbinsx,nbinsy],density=1,range=[[-180,180],[-180,180]])
fig.colorbar
[a,b]=np.meshgrid(xbins,ybins)
a=(a.transpose())
b=(b.transpose())
#plt.title('AI Charmm')
plt.xlabel(r'$\chi_1$')
plt.ylabel(r'$\chi_3$')
plt.savefig('ramaAIcR.pdf')
plt.show()


gfile=open("datagnu_AIcr.txt", "w")
delx=xbins[1]-xbins[0]
dely=ybins[1]-ybins[0]
for i in range(len(xbins[:-1])): 
    for  j in range(len(ybins[:-1])): 
        gfile.write('%3f %3f %3f\n' % (xbins[i]+delx/2,ybins[j]+dely/2,hist2d[i,j]))
    gfile.write('\n') 
gfile.close()

# %%
#try14 hbnum per strand
hbnum14g = np.loadtxt('try14/letfree/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN14g = np.loadtxt('try14/letfree/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB14g = np.loadtxt('try14/letfree/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try14_Charmm hbnum per strand
hbnum14c = np.loadtxt('try14_Charmm/analysis_merve/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN14c= np.loadtxt('try14_Charmm/analysis_merve/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB14c = np.loadtxt('try14_Charmm/analysis_merve/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13 hbnum per strand
hbnum13g = np.loadtxt('try13/letfree/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN13g = np.loadtxt('try13/letfree/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB13g = np.loadtxt('try13/letfree/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try14_Charmm hbnum per strand
hbnum13c = np.loadtxt('try13_Charmm/analysis_merve/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN13c= np.loadtxt('try13_Charmm/analysis_merve/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB13c = np.loadtxt('try13_Charmm/analysis_merve/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#prep for conversion to dataframe
hbnum = np.hstack((hbnum14g,hbnum13g,hbnum14c,hbnum13c))
hbnumGLN = np.hstack((hbnumGLN14g,hbnumGLN13g,hbnumGLN14c,hbnumGLN13c))
hbnumGLNBB = np.hstack((hbnumGLNBB14g,hbnumGLNBB13g,hbnumGLNBB14c,hbnumGLNBB13c))
ff = np.hstack((np.repeat('SI Gromos',len(hbnum14g)),np.repeat('AI Gromos',len(hbnum13g)),np.repeat('SI Charmm', len(hbnum14c)),np.repeat('AI Charmm',len(hbnum13c))))
fff = np.hstack((np.repeat('Gromos',len(hbnum14g)+len(hbnum13g)),np.repeat('Charmm',len(hbnum14c)+len(hbnum13c))))

#convert np arrays into dataframe for each type of hbod
d = {'BB-BB': hbnum, 'SC-SC': hbnumGLN, 'BB-SC': hbnumGLNBB}
hbps = DataFrame(data=d)
hbps['System'] = ff
hbps['Force Field'] = fff

bbbb=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbbb=(bbbb.map(sns.kdeplot,'BB-BB', common_norm=0))
bbbb.add_legend()
plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('bb-bb.pdf')
plt.show()

bbsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbsc=(bbsc.map(sns.kdeplot,'BB-SC', common_norm=0))
bbsc.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('bb-sc.pdf')
plt.show()

scsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scsc=(scsc.map(sns.kdeplot,'SC-SC', common_norm=0))
scsc.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('sc-sc.pdf')
plt.show()

# %%
#try14 hbnum per strand RESTRAINT
hbnum14gR = np.loadtxt('try14/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN14gR = np.loadtxt('try14/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB14gR = np.loadtxt('try14/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13 hbnum per strand RESTRAINT
hbnum13gR = np.loadtxt('try13/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN13gR = np.loadtxt('try13/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB13gR = np.loadtxt('try13/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try14 charmm hbnum per strand RESTRAINT
hbnum14cR = np.loadtxt('try14_Charmm/restraint/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN14cR = np.loadtxt('try14_Charmm/restraint/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB14cR = np.loadtxt('try14_Charmm/restraint/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13 charmm hbnum per strand RESTRAINT
hbnum13cR = np.loadtxt('try13_Charmm/restraint/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN13cR = np.loadtxt('try13_Charmm/restraint/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB13cR = np.loadtxt('try13_Charmm/restraint/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32


#prep for conversion to dataframe
hbnumR = np.hstack((hbnum14gR,hbnum14g,hbnum13gR,hbnum13g))
hbnumGLNR = np.hstack((hbnumGLN14gR,hbnumGLN14g,hbnumGLN13gR,hbnumGLN13g))
hbnumGLNBBR = np.hstack((hbnumGLNBB14gR,hbnumGLNBB14g,hbnumGLNBB13gR,hbnumGLNBB13g))
ffr = np.hstack((np.repeat('SI Gromos Rest',len(hbnum14gR)),np.repeat('SI Gromos',len(hbnum14g)),np.repeat('AI Gromos Rest', len(hbnum13gR)),np.repeat('AI Gromos',len(hbnum13g))))

#convert np arrays into dataframe for each type of hbod
dR = {'BB-BB': hbnumR, 'SC-SC': hbnumGLNR, 'BB-SC': hbnumGLNBBR}
hbpsR = DataFrame(data=dR)
hbpsR['System'] = ffr

bbbbgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbbbgr=(bbbbgr.map(sns.kdeplot,'BB-BB', common_norm=0))
bbbbgr.add_legend()
plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('bb-bbG.pdf')
plt.show()

bbscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbscgr=(bbscgr.map(sns.kdeplot,'BB-SC', common_norm=0))
bbscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('bb-scG.pdf')
plt.show()

scscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scscgr=(scscgr.map(sns.kdeplot,'SC-SC', common_norm=0))
scscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('sc-scG.pdf')
plt.show()

# %%
#prep for conversion to dataframe
hbnumcR = np.hstack((hbnum14cR,hbnum14c,hbnum13cR,hbnum13c))
hbnumGLNcR = np.hstack((hbnumGLN14cR,hbnumGLN14c,hbnumGLN13cR,hbnumGLN13c))
hbnumGLNBBcR = np.hstack((hbnumGLNBB14cR,hbnumGLNBB14c,hbnumGLNBB13cR,hbnumGLNBB13c))
ffcr = np.hstack((np.repeat('SI Charmm Rest',len(hbnum14cR)),np.repeat('SI Charmm',len(hbnum14c)),np.repeat('AI Charmm Rest', len(hbnum13cR)),np.repeat('AI Charmm',len(hbnum13c))))

#convert np arrays into dataframe for each type of hbod
dcR = {'BB-BB': hbnumcR, 'SC-SC': hbnumGLNcR, 'BB-SC': hbnumGLNBBcR}
hbpscR = DataFrame(data=dcR)
hbpscR['System'] = ffcr

#plot the kde curves
#colorscr={'SI Charmm': 'blue', 'AI Charmm': 'red', 'SI Charmm Rest': 'darkblue', 'AI Charmm Rest': 'darkred'}
#sns.displot(data=hbpscR ,kind='kde' , hue= 'System' , x = 'BB-BB', common_norm=False, palette=colorscr)
#sns.displot(data=hbpscR ,kind='kde' , hue= 'System' , x = 'SC-SC', common_norm=False, palette=colorscr)
#sns.displot(data=hbpscR ,kind='kde' , hue= 'System' , x = 'BB-SC', common_norm=False, palette=colorscr)
#plt.show()

bbbbcr=sns.FacetGrid(data=hbpscR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbbbcr=(bbbbcr.map(sns.kdeplot,'BB-BB', common_norm=0))
bbbbcr.add_legend()
plt.xticks(np.arange(11.4,13.2,step=0.2))
plt.savefig('bb-bbC.pdf')
plt.show()

bbsccr=sns.FacetGrid(data=hbpscR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbsccr=(bbsccr.map(sns.kdeplot,'BB-SC', common_norm=0))
bbsccr.add_legend()
plt.xticks(np.arange(4.5,8.5,step=0.5))
plt.savefig('bb-scC.pdf')
plt.show()

scsccr=sns.FacetGrid(data=hbpscR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scsccr=(scsccr.map(sns.kdeplot,'SC-SC', common_norm=0))
scsccr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('sc-scC.pdf')
plt.show()

# %%
# %cd try14 
# %cd analysis

# !seq 1 11 |gmx energy -f rerun.edr -b 20 -o energyall.xvg 2>/dev/null |tail -n 76 |awk '{gsub(/[[:blank:]]/, "", $1); for (i = 1; i <= NF; i++) {$i = sprintf("%12s", $i)} print }' FS="   *" OFS="                  "  > enerout
# %cd ../letfree
# %cd analysis
# %cd ../../
# Out:
# [Errno 2] No such file or directory: 'try14'
# /media/merve/Seagate Expansion Drive/sg12
# [Errno 2] No such file or directory: 'analysis'
# /media/merve/Seagate Expansion Drive/sg12
# /bin/bash: enerout: Permission denied
# [Errno 2] No such file or directory: '../letfree/analysis'
# /media/merve/Seagate Expansion Drive/sg12
# /media/merve

# %%
#try14 hbnum per strand
hbnum14gn = np.loadtxt('try14_newrest/letfree/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN14gn = np.loadtxt('try14_newrest/letfree/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB14gn = np.loadtxt('try14_newrest/letfree/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try14_Charmm hbnum per strand
hbnum14gnr = np.loadtxt('try14_newrest/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN14gnr= np.loadtxt('try14_newrest/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB14gnr = np.loadtxt('try14_newrest/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#prep for conversion to dataframe
hbnumn = np.hstack((hbnum14gn,hbnum14gnr))
hbnumGLNn = np.hstack((hbnumGLN14gn,hbnumGLN14gnr))
hbnumGLNBBn = np.hstack((hbnumGLNBB14gn,hbnumGLNBB14gnr))
ff = np.hstack((np.repeat('SI Gromos',len(hbnum14gn)),np.repeat('SI Gromos rest',len(hbnum14gnr))))
#fff = np.hstack((np.repeat('Gromos',len(hbnum14g)+len(hbnum13g)),np.repeat('Charmm',len(hbnum14c)+len(hbnum13c))))

#convert np arrays into dataframe for each type of hbod
d = {'BB-BB': hbnumn, 'SC-SC': hbnumGLNn, 'BB-SC': hbnumGLNBBn}
hbps = DataFrame(data=d)
hbps['System'] = ff
#hbps['Force Field'] = fff

bbbb=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','b']},height=5.5)
bbbb=(bbbb.map(sns.kdeplot,'BB-BB', common_norm=0))
bbbb.add_legend()
plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('bb-bb.pdf')
plt.show()
bbsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','b']},height=5.5)
#bbsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbsc=(bbsc.map(sns.kdeplot,'BB-SC', common_norm=0))
bbsc.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('bb-sc.pdf')
plt.show()
scsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','b']},height=5.5)
#scsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scsc=(scsc.map(sns.kdeplot,'SC-SC', common_norm=0))
scsc.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
plt.savefig('sc-sc.pdf')
plt.show()

# %%
#try13 hbnum per strand
hbnum13gn = np.loadtxt('210824_try13new/letfree/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/64
hbnumGLN13gn = np.loadtxt('210824_try13new/letfree/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/64
hbnumGLNBB13gn = np.loadtxt('210824_try13new/letfree/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#try13_Charmm hbnum per strand
hbnum13gnr = np.loadtxt('210824_try13new/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/64
hbnumGLN13gnr= np.loadtxt('210824_try13new/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/64
hbnumGLNBB13gnr = np.loadtxt('210824_try13new/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#try13 hbnum per strand
hbnum14gn = np.loadtxt('210824_try14new/letfree/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/64
hbnumGLN14gn = np.loadtxt('210824_try14new/letfree/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/64
hbnumGLNBB14gn = np.loadtxt('210824_try14new/letfree/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#try13_Charmm hbnum per strand
hbnum14gnr = np.loadtxt('210824_try14new/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/64
hbnumGLN14gnr= np.loadtxt('210824_try14new/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/64
hbnumGLNBB14gnr = np.loadtxt('210824_try14new/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#prep for conversion to dataframe
hbnumgn = np.hstack((hbnum14gnr,hbnum14gn,hbnum13gnr,hbnum13gn))
hbnumGLNgn = np.hstack((hbnumGLN14gnr,hbnumGLN14gn,hbnumGLN13gnr,hbnumGLN13gn))
hbnumGLNBBgn = np.hstack((hbnumGLNBB14gnr,hbnumGLNBB14gn,hbnumGLNBB13gnr,hbnumGLNBB13gn))
ffr = np.hstack((np.repeat('SI Gromos Rest',len(hbnum14gnr)),np.repeat('SI Gromos',len(hbnum14gn)),np.repeat('AI Gromos Rest', len(hbnum13gnr)),np.repeat('AI Gromos',len(hbnum13gn))))

#convert np arrays into dataframe for each type of hbod
dR = {'BB-BB': hbnumgn, 'SC-SC': hbnumGLNgn, 'BB-SC': hbnumGLNBBgn}
hbpsR = DataFrame(data=dR)
hbpsR['System'] = ffr
print('aat298K')
bbbbgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbbbgr=(bbbbgr.map(sns.kdeplot,'BB-BB', common_norm=0))
bbbbgr.add_legend()
plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-bbG.pdf')
plt.show()

bbscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbscgr=(bbscgr.map(sns.kdeplot,'BB-SC', common_norm=0))
bbscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-scG.pdf')
plt.show()

scscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scscgr=(scscgr.map(sns.kdeplot,'SC-SC', common_norm=0))
scscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('sc-scG.pdf')
plt.show()
# Out:
# aat298K

# %%
#try14 hbnum per strand
hbnum14gn100 = np.loadtxt('210825_try14new100k/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/64
hbnumGLN14gn100 = np.loadtxt('210825_try14new100k/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/64
hbnumGLNBB14gn100 = np.loadtxt('210825_try14new100k/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#try14_Charmm hbnum per strand
hbnum13gn100 = np.loadtxt('210825_try13new100k/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/64
hbnumGLN13gn100= np.loadtxt('210825_try13new100k/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/64
hbnumGLNBB13gn100 = np.loadtxt('210825_try13new100k/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#try14 hbnum per strand
hbnum14gn100apt = np.loadtxt('apt14/100K/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN14gn100apt = np.loadtxt('apt14/100K/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB14gn100apt = np.loadtxt('apt14/100K/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try14_Charmm hbnum per strand
hbnum13gn100apt = np.loadtxt('apt13/100K/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN13gn100apt= np.loadtxt('apt13/100K/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB13gn100apt = np.loadtxt('apt13/100K/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32
#prep for conversion to dataframe
hbnumn = np.hstack((hbnum14gn100,hbnum13gn100,hbnum14gn100apt,hbnum13gn100apt))
hbnumGLNn = np.hstack((hbnumGLN14gn100,hbnumGLN13gn100,hbnumGLN14gn100apt,hbnumGLN13gn100apt))
hbnumGLNBBn = np.hstack((hbnumGLNBB14gn100,hbnumGLNBB13gn100,hbnumGLNBB14gn100apt,hbnumGLNBB13gn100apt))
ff = np.hstack((np.repeat('SI Gromos AaT',len(hbnum14gn100)),np.repeat('AI Gromos AaT',len(hbnum13gn100)),np.repeat('SI Gromos ApT',len(hbnum14gn100apt)),np.repeat('AI Gromos ApT',len(hbnum13gn100apt))))
#fff = np.hstack((np.repeat('Gromos',len(hbnum14g)+len(hbnum13g)),np.repeat('Charmm',len(hbnum14c)+len(hbnum13c))))

#convert np arrays into dataframe for each type of hbod
d = {'BB-BB': hbnumn, 'SC-SC': hbnumGLNn, 'BB-SC': hbnumGLNBBn}
hbps = DataFrame(data=d)
hbps['System'] = ff
#hbps['Force Field'] = fff
print(hbps)
print('aat apt 100K')

bbbb=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'],'ls': ['-','--','-','--']},height=5.5)
bbbb=(bbbb.map(sns.kdeplot,'BB-BB', bw_adjust= 2,common_norm=0))
bbbb.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-bb.pdf')
plt.show()
bbsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'],'ls': ['-','--','-','--']},height=5.5)
#bbsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbsc=(bbsc.map(sns.kdeplot,'BB-SC', common_norm=0))
bbsc.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-sc.pdf')
plt.show()
scsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'],'ls': ['-','--','-','--']},height=5.5)
#scsc=sns.FacetGrid(data=hbps, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scsc=(scsc.map(sns.kdeplot,'SC-SC', bw_adjust = 2.5,  common_norm=0))
scsc.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('sc-sc.pdf')
plt.show()
# Out:
#            BB-BB     SC-SC      BB-SC         System
# 0      12.890625  12.90625  11.281250  SI Gromos AaT
# 1      12.875000  12.90625  11.390625  SI Gromos AaT
# 2      12.921875  12.93750  11.515625  SI Gromos AaT
# 3      12.953125  12.90625  11.437500  SI Gromos AaT
# 4      12.937500  12.90625  11.421875  SI Gromos AaT
# ...          ...       ...        ...            ...
# 23125  12.093750  12.68750   9.500000  AI Gromos ApT
# 23126  12.031250  12.78125   9.187500  AI Gromos ApT
# 23127  12.281250  12.71875   9.437500  AI Gromos ApT
# 23128  12.187500  12.75000   9.218750  AI Gromos ApT
# 23129  12.062500  12.71875   9.281250  AI Gromos ApT
#
# [23130 rows x 4 columns]
# aat apt 100K

# %%
#try13 hbnum per strand
hbnum13gnapt = np.loadtxt('apt13/letfree/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN13gnapt = np.loadtxt('apt13/letfree/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB13gnapt = np.loadtxt('apt13/letfree/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13_Charmm hbnum per strand
hbnum13gnrapt = np.loadtxt('apt13/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN13gnrapt= np.loadtxt('apt13/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB13gnrapt = np.loadtxt('apt13/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13 hbnum per strand
hbnum14gnapt = np.loadtxt('apt14/letfree/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN14gnapt = np.loadtxt('apt14/letfree/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB14gnapt = np.loadtxt('apt14/letfree/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13_Charmm hbnum per strand
hbnum14gnrapt = np.loadtxt('apt14/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN14gnrapt= np.loadtxt('apt14/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB14gnrapt = np.loadtxt('apt14/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#prep for conversion to dataframe
hbnumgn = np.hstack((hbnum14gnrapt,hbnum14gnapt,hbnum13gnrapt,hbnum13gnapt))
hbnumGLNgn = np.hstack((hbnumGLN14gnrapt,hbnumGLN14gnapt,hbnumGLN13gnrapt,hbnumGLN13gnapt))
hbnumGLNBBgn = np.hstack((hbnumGLNBB14gnrapt,hbnumGLNBB14gnapt,hbnumGLNBB13gnrapt,hbnumGLNBB13gnapt))
ffr = np.hstack((np.repeat('SI Gromos Rest',len(hbnum14gnrapt)),np.repeat('SI Gromos',len(hbnum14gnapt)),np.repeat('AI Gromos Rest', len(hbnum13gnrapt)),np.repeat('AI Gromos',len(hbnum13gnapt))))

#convert np arrays into dataframe for each type of hbod
dR = {'BB-BB': hbnumgn, 'SC-SC': hbnumGLNgn, 'BB-SC': hbnumGLNBBgn}
hbpsR = DataFrame(data=dR)
hbpsR['System'] = ffr
print('apt298K')

bbbbgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbbbgr=(bbbbgr.map(sns.kdeplot,'BB-BB', common_norm=0))
bbbbgr.add_legend()
plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-bbG.pdf')
plt.show()

bbscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbscgr=(bbscgr.map(sns.kdeplot,'BB-SC', common_norm=0))
bbscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-scG.pdf')
plt.show()

scscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scscgr=(scscgr.map(sns.kdeplot,'SC-SC', common_norm=0))
scscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('sc-scG.pdf')
plt.show()
# Out:
# apt298K
# /home/merve/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/merve/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#try13 hbnum per strand
hbnum13gnapt10 = np.loadtxt('10K/210827_try13apt10k/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/32
hbnumGLN13gnapt10 = np.loadtxt('10K/210827_try13apt10k/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/32
hbnumGLNBB13gnapt10 = np.loadtxt('10K/210827_try13apt10k/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13_Charmm hbnum per strand
hbnum14gnapt10 = np.loadtxt('10K/210827_try14apt10k/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/32
hbnumGLN14gnapt10= np.loadtxt('10K/210827_try14apt10k/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/32
hbnumGLNBB14gnapt10 = np.loadtxt('10K/210827_try14apt10k/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/32

#try13 hbnum per strand
hbnum14gnaat10 = np.loadtxt('10K/210826_try14new10k/analysis/hbnum-all.xvg',skiprows=25, usecols=1)/64
hbnumGLN14gnaat10 = np.loadtxt('10K/210826_try14new10k/analysis/hbnumGLN-all.xvg',skiprows=25, usecols=1)/64
hbnumGLNBB14gnaat10 = np.loadtxt('10K/210826_try14new10k/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#try13_Charmm hbnum per strand
hbnum13gnaat10 = np.loadtxt('10K/210826_try13new10k/analysis/hbnum-all.xvg',skiprows=25,usecols=1)/64
hbnumGLN13gnaat10= np.loadtxt('10K/210826_try13new10k/analysis/hbnumGLN-all.xvg',skiprows=25,usecols=1)/64
hbnumGLNBB13gnaat10 = np.loadtxt('10K/210826_try13new10k/analysis/hbnumGLN-BB-all.xvg',skiprows=25,usecols=1)/64

#prep for conversion to dataframe
hbnumgn = np.hstack((hbnum14gnaat10,hbnum13gnaat10,hbnum14gnapt10,hbnum13gnapt10))
hbnumGLNgn = np.hstack((hbnumGLN14gnaat10,hbnumGLN13gnaat10,hbnumGLN14gnapt10,hbnumGLN13gnapt10))
hbnumGLNBBgn = np.hstack((hbnumGLNBB14gnaat10,hbnumGLNBB13gnaat10,hbnumGLNBB14gnapt10,hbnumGLNBB13gnapt10))
ffr = np.hstack((np.repeat('SI Gromos AAT',len(hbnum14gnaat10)),np.repeat('AI Gromos AAT',len(hbnum13gnaat10)),np.repeat('SI Gromos APT', len(hbnum14gnapt10)),np.repeat('AI Gromos APT',len(hbnum13gnapt10))))

#convert np arrays into dataframe for each type of hbod
dR = {'BB-BB': hbnumgn, 'SC-SC': hbnumGLNgn, 'BB-SC': hbnumGLNBBgn}
hbpsR = DataFrame(data=dR)
hbpsR['System'] = ffr
print('apt aat 10K')
bbbbgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbbbgr=(bbbbgr.map(sns.kdeplot,'BB-BB', common_norm=0, bw_adjust = 2))
bbbbgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-bbG.pdf')
plt.show()

bbscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
bbscgr=(bbscgr.map(sns.kdeplot,'BB-SC', common_norm=0))
bbscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('bb-scG.pdf')
plt.show()

scscgr=sns.FacetGrid(data=hbpsR, hue='System', hue_kws = {'color':['r','r','b','b'], 'ls': ['-','--','-','--']},height=5.5)
scscgr=(scscgr.map(sns.kdeplot,'SC-SC', common_norm=0, bw_adjust=4))
scscgr.add_legend()
#plt.xticks(np.arange(11,13.2,step=0.2))
#plt.savefig('sc-scG.pdf')
plt.show()
# Out:
# apt aat 10K
# /home/merve/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/merve/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
